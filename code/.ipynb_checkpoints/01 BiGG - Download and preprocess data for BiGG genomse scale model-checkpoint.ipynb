# %%
from downloading_BiGG_models import *
import json

# %%
model_IDs = ["e_coli_core", "iAB_RBC_283", "iAF1260", "iAF1260b", "iAF692", "iAF987", "iAM_Pb448",
             "iAM_Pc455", "iAM_Pf480", "iAM_Pk459", "iAM_Pv461", "iAPECO1_1312", "iAT_PLT_636",
             "iB21_1397", "iBWG_1329", "ic_1306", "iCHOv1", "iCHOv1_DG44", "iCN718", "iCN900", "iE2348C_1286",
            "iEC042_1314", "iEC1344_C", "iEC1349_Crooks", "iEC1356_Bl21DE3", "iEC1364_W",
            "iEC1368_DH5a", "iEC1372_W3110", "iEC55989_1330", "iECABU_c1320", "iECB_1328", "iECBD_1354",
            "iECD_1391", "iECDH10B_1368", "iEcDH1_1363", "iECDH1ME8569_1439", "iEcE24377_1341",
            "iECED1_1282", "iECH74115_1262", "iEcHS_1320", "iECIAI1_1343", "iECIAI39_1322", 
            "iECNA114_1301", "iECO103_1326", "iECO111_1330", "iECO26_1355", "iECOK1_1307", "iEcolC_1368",
            "iECP_1309", "iECs_1301", "iECS88_1305", "iECSE_1348", "iECSF_1327", "iEcSMS35_1347",
            "iECSP_1301", "iECUMN_1333", "iECW_1372", "iEK1008", "iEKO11_1354", "iETEC_1333", "iG2583_1286",
            "iHN637", "iIS312", 
             "iIS312_Amastigote", "iIS312_Epimastigote", "iIS312_Trypomastigote", "iIT341", "iJB785", "iJN1463",
            "iJN678", "iJN746", "iJO1366", "iJR904", "iLB1027_lipid", "iLF82_1304", "iLJ478", "iML1515",
            "iMM1415", "iMM904", "iND750", "iNF517", "iNJ661", "iNRG857_1313", "iPC815", "iRC1080",
            "iS_1188", "iSB619", "iSbBS512_1146", "iSBO_1134", "iSDY_1059", "iSF_1195", "iSFV_1184", 
            "iSFxv_1172", "iSSON_1240", "iSynCJ816", "iUMN146_1321", "iUMNK88_1353", "iUTI89_1310", 
            "iWFL_1372", "iY75_1357", "iYL1228", "iYO844", "iYS1720", "iYS854", "iZ_1308", "RECON1",
            "Recon3D", "STM_v1_0"]

# %%
#model_IDs = ["e_coli_core", "iAF1260", "iAF1260b", "iAF692", "iAF987"]

# %% [markdown]
# #### Create reaction DataFrame for all BiGG models and text files with all genes in the model:

# %%
for model_ID in model_IDs:
    print(model_ID)
    
    try:
        os.mkdir(join(datasets_dir, "BiGG_GSM", model_ID))
    
        model_metabolites, model_reactions, df_reactions = download_model_information(bigg_ID = model_ID)
        model_metabolites_list = [met["id"] for met in model_metabolites]
        model_reactions_list = [reaction["id"] for reaction in model_reactions]
        with open(join(datasets_dir, "BiGG_GSM", model_ID, 'model_metabolites.txt'), 'w') as outfile:
            json.dump(model_metabolites, outfile)
        np.save(join(datasets_dir, "BiGG_GSM", model_ID, 'model_metabolites_list.npy'),
                model_metabolites_list)    

        df_reactions = process_reactions_DataFrame(df_reactions, model_reactions, model_reactions_list)
        print("There are enzymatic %s reactions" % len(df_reactions))
        print("Reactions without gene reaction rules: %s" %len(df_reactions.loc[df_reactions["gene_reaction_rule"] == ""]))

        create_txt_file_with_all_genes(df_reactions, model_ID)

        df_reactions.to_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))
    
    except FileExistsError: pass
# Out:
# iAF692
# Removing 124 non-enzymatic reactions
# There are enzymatic 815 reactions
# Reactions without gene reaction rules: 91
# Txt-file with all genes is saved at: ..\..\datasets\BiGG_GSM\iAF692\gene_numbers_iAF692.txt

# %%
df_reactions.loc[df_reactions["BiGG reaction ID"] == "ACLS"]
# Out:
#    BiGG reaction ID          reaction name           gene_reaction_rule  \
# 61             ACLS  Acetolactate synthase                  (Mbar_A0219
# 62             ACLS  Acetolactate synthase  Mbar_A0210) and (Mbar_A2541
# 63             ACLS  Acetolactate synthase                   Mbar_A0428
# 64             ACLS  Acetolactate synthase                   Mbar_A0438
# 65             ACLS  Acetolactate synthase                  Mbar_A0218)
#
#    direction                                        metabolites         EC  \
# 61   forward  {'alac__S_c': 1.0, 'co2_c': 1.0, 'h_c': -1.0, ...  [2.2.1.6]
# 62   forward  {'alac__S_c': 1.0, 'co2_c': 1.0, 'h_c': -1.0, ...  [2.2.1.6]
# 63   forward  {'alac__S_c': 1.0, 'co2_c': 1.0, 'h_c': -1.0, ...  [2.2.1.6]
# 64   forward  {'alac__S_c': 1.0, 'co2_c': 1.0, 'h_c': -1.0, ...  [2.2.1.6]
# 65   forward  {'alac__S_c': 1.0, 'co2_c': 1.0, 'h_c': -1.0, ...  [2.2.1.6]
#
#       substrates            products                     genes
# 61  [h_c, pyr_c]  [alac__S_c, co2_c]              [Mbar_A0219]
# 62  [h_c, pyr_c]  [alac__S_c, co2_c]  [Mbar_A0210, Mbar_A2541]
# 63  [h_c, pyr_c]  [alac__S_c, co2_c]              [Mbar_A0428]
# 64  [h_c, pyr_c]  [alac__S_c, co2_c]              [Mbar_A0438]
# 65  [h_c, pyr_c]  [alac__S_c, co2_c]              [Mbar_A0218]

# %% [markdown]
# #### Use the created files as the input for the Uniprot mapping service

# %%
model_IDs = os.listdir(join(datasets_dir, "BiGG_GSM"))

# %% [markdown]
# Load and map the results:

# %%
for model_ID in model_IDs:
    print(model_ID)
    df_reactions = pd.read_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))
    df_reactions = add_Uniprot_IDs(df_reactions, model_ID)
    print("For %s out of %s reactions we don't have a Uniprot ID, yet." % 
          (len(df_reactions.loc[pd.isnull(df_reactions["Uniprot ID"])]), len(df_reactions)))
    #get links for quick go mapping for Uniprot IDs:
    get_Quick_GO_links_for_enzyme_complexes(df_reactions, model_ID)
    df_reactions.to_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))
    print(" ")
# Out:
# iAF692
# For 187 out of 815 reactions we don't have a Uniprot ID, yet.

# %% [markdown]
# #### Downloading information about binding site from https://www.ebi.ac.uk/QuickGO via the Uniprot IDs:

# %%
print(model_ID)
df_reactions = pd.read_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))

GO_df = load_GO_DataFrames(model_ID)
GO_UIDs = list(set(GO_df["GENE PRODUCT ID"]))
df_reactions = add_Uniprot_ID_for_enzyme_complexes(df_reactions, GO_UIDs)

print("For %s out of %s reactions we don't have a Uniprot ID." % 
      (len(df_reactions.loc[pd.isnull(df_reactions["Uniprot ID"])]), len(df_reactions)))
df_reactions.to_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))


with open(join(datasets_dir, "BiGG_GSM", model_ID, 'model_metabolites.txt')) as json_file:
    model_metabolites = json.load(json_file)
model_metabolites_list = list(np.load(join(datasets_dir, "BiGG_GSM", model_ID, 'model_metabolites_list.npy')))

df_KM = create_KM_DataFrame(df_reactions)
# Out:
# iAF692
# For 149 out of 815 reactions we don't have a Uniprot ID.

# %%
model_IDs = os.listdir("..\\..\\data\\BiGG_GSM")

# %%
for model_ID in model_IDs[0:]:
    print(model_ID)
    df_reactions = pd.read_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))
    
    GO_df = load_GO_DataFrames(model_ID)
    GO_UIDs = list(set(GO_df["GENE PRODUCT ID"]))
    df_reactions = add_Uniprot_ID_for_enzyme_complexes(df_reactions, GO_UIDs)
    
    print("For %s out of %s reactions we don't have a Uniprot ID." % 
          (len(df_reactions.loc[pd.isnull(df_reactions["Uniprot ID"])]), len(df_reactions)))
    df_reactions.to_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_reactions.pkl"))
    
    
    with open(join(datasets_dir, "BiGG_GSM", model_ID, 'model_metabolites.txt')) as json_file:
        model_metabolites = json.load(json_file)
    model_metabolites_list = list(np.load(join(datasets_dir, "BiGG_GSM", model_ID, 'model_metabolites_list.npy')))
    
    df_KM = create_KM_DataFrame(df_reactions)
    df_KM = get_kegg_and_bigg_compound_ids(df_KM,  model_metabolites, model_metabolites_list)
    df_KM = add_substrate_name(df_KM)
    df_KM = find_KEGG_ID_by_synonym(df_KM)
    df_KM = download_SMILES_or_KEGG_from_MetaNetX(df_KM)
    df_KM = remove_small_mets(df_KM)
    df_KM.to_pickle(join(datasets_dir, "BiGG_GSM", model_ID, "df_KM_checkpoint_" + model_ID + ".pkl"))
    
    print("There are %s KM data points" % len(df_KM))
    print("Data points without KEGG ID and SMILES: %s" 
          # %len(df_KM.loc[pd.isnull(df_KM["KEGG ID"])].loc[pd.isnull(df_KM["SMILES"])]))
    print("Data points without Uniprot ID: %s" 
          # %len(df_KM.loc[pd.isnull(df_KM["Uniprot ID"])]))
    print("Data points without KEGG ID, SMILES and Uniprot ID: %s" 
          # %len(df_KM.loc[pd.isnull(df_KM["KEGG ID"])].loc[pd.isnull(df_KM["SMILES"])].loc[pd.isnull(df_KM["Uniprot ID"])]))
    
    print(" ")
# Out:
# e_coli_core
# For 16 out of 86 reactions we don't have a Uniprot ID.
# There are 312 KM data points
# Data points without KEGG ID and SMILES: 5
# Data points without Uniprot ID: 66
# Data points without KEGG ID, SMILES and Uniprot ID: 3
#
# iAF1260
# For 234 out of 1800 reactions we don't have a Uniprot ID.
# There are 6402 KM data points
# Data points without KEGG ID and SMILES: 789
# Data points without Uniprot ID: 903
# Data points without KEGG ID, SMILES and Uniprot ID: 169
#
# iAF1260b
# For 235 out of 1801 reactions we don't have a Uniprot ID.
# There are 6406 KM data points
# Data points without KEGG ID and SMILES: 789
# Data points without Uniprot ID: 907
# Data points without KEGG ID, SMILES and Uniprot ID: 169
#
# iAF692
# For 149 out of 815 reactions we don't have a Uniprot ID.
# There are 3195 KM data points
# Data points without KEGG ID and SMILES: 226
# Data points without Uniprot ID: 566
# Data points without KEGG ID, SMILES and Uniprot ID: 68
#
# iAF987
# For 128 out of 1698 reactions we don't have a Uniprot ID.
# There are 6391 KM data points
# Data points without KEGG ID and SMILES: 945
# Data points without Uniprot ID: 500
# Data points without KEGG ID, SMILES and Uniprot ID: 103
#
# iAM_Pc455
# For 155 out of 1237 reactions we don't have a Uniprot ID.
# There are 4816 KM data points
# Data points without KEGG ID and SMILES: 978
# Data points without Uniprot ID: 532
# Data points without KEGG ID, SMILES and Uniprot ID: 142
#
# iAM_Pf480
# For 244 out of 1352 reactions we don't have a Uniprot ID.
# There are 5434 KM data points
# Data points without KEGG ID and SMILES: 1048
# Data points without Uniprot ID: 900
# Data points without KEGG ID, SMILES and Uniprot ID: 269
#
# iAM_Pk459
# For 155 out of 1211 reactions we don't have a Uniprot ID.
# There are 4697 KM data points
# Data points without KEGG ID and SMILES: 962
# Data points without Uniprot ID: 536
# Data points without KEGG ID, SMILES and Uniprot ID: 142
#
# iAM_Pv461
# For 161 out of 1220 reactions we don't have a Uniprot ID.
# There are 4713 KM data points
# Data points without KEGG ID and SMILES: 981
# Data points without Uniprot ID: 554
# Data points without KEGG ID, SMILES and Uniprot ID: 144
#
# iCN900
# For 303 out of 1356 reactions we don't have a Uniprot ID.
# There are 5167 KM data points
# Data points without KEGG ID and SMILES: 418
# Data points without Uniprot ID: 1179
# Data points without KEGG ID, SMILES and Uniprot ID: 161
#
# iEC55989_1330
# For 266 out of 1983 reactions we don't have a Uniprot ID.
# There are 7114 KM data points
# Data points without KEGG ID and SMILES: 970
# Data points without Uniprot ID: 1013
# Data points without KEGG ID, SMILES and Uniprot ID: 266
#
# iEcSMS35_1347
# For 270 out of 1995 reactions we don't have a Uniprot ID.
# There are 7157 KM data points
# Data points without KEGG ID and SMILES: 981
# Data points without Uniprot ID: 1034
# Data points without KEGG ID, SMILES and Uniprot ID: 264
#
# iECs_1301
# For 820 out of 1956 reactions we don't have a Uniprot ID.
# There are 7025 KM data points
# Data points without KEGG ID and SMILES: 981
# Data points without Uniprot ID: 2922
# Data points without KEGG ID, SMILES and Uniprot ID: 498
#
# iECUMN_1333
# For 293 out of 1980 reactions we don't have a Uniprot ID.
# There are 7090 KM data points
# Data points without KEGG ID and SMILES: 963
# Data points without Uniprot ID: 1109
# Data points without KEGG ID, SMILES and Uniprot ID: 260
#
# iECW_1372
# For 269 out of 2020 reactions we don't have a Uniprot ID.
# There are 7238 KM data points
# Data points without KEGG ID and SMILES: 995
# Data points without Uniprot ID: 1027
# Data points without KEGG ID, SMILES and Uniprot ID: 269
#
# iEK1008
# For 286 out of 3125 reactions we don't have a Uniprot ID.
# There are 18727 KM data points
# Data points without KEGG ID and SMILES: 2455
# Data points without Uniprot ID: 1357
# Data points without KEGG ID, SMILES and Uniprot ID: 210
#
# iETEC_1333
# For 270 out of 1993 reactions we don't have a Uniprot ID.
# There are 7158 KM data points
# Data points without KEGG ID and SMILES: 995
# Data points without Uniprot ID: 1026
# Data points without KEGG ID, SMILES and Uniprot ID: 267
#
# iG2583_1286
# For 263 out of 1937 reactions we don't have a Uniprot ID.
# There are 6954 KM data points
# Data points without KEGG ID and SMILES: 953
# Data points without Uniprot ID: 1011
# Data points without KEGG ID, SMILES and Uniprot ID: 256
#
# iJN1463
# For 345 out of 2458 reactions we don't have a Uniprot ID.
# There are 9084 KM data points
# Data points without KEGG ID and SMILES: 1874
# Data points without Uniprot ID: 1247
# Data points without KEGG ID, SMILES and Uniprot ID: 253
#
# iJN678
# For 158 out of 834 reactions we don't have a Uniprot ID.
# There are 3199 KM data points
# Data points without KEGG ID and SMILES: 232
# Data points without Uniprot ID: 600
# Data points without KEGG ID, SMILES and Uniprot ID: 33
#
# iJN746
# For 134 out of 902 reactions we don't have a Uniprot ID.
# There are 3345 KM data points
# Data points without KEGG ID and SMILES: 212
# Data points without Uniprot ID: 483
# Data points without KEGG ID, SMILES and Uniprot ID: 28
#
# iJO1366
# For 260 out of 1947 reactions we don't have a Uniprot ID.
# There are 6984 KM data points
# Data points without KEGG ID and SMILES: 980
# Data points without Uniprot ID: 1023
# Data points without KEGG ID, SMILES and Uniprot ID: 259
#
# iJR904
# For 118 out of 909 reactions we don't have a Uniprot ID.
# There are 3414 KM data points
# Data points without KEGG ID and SMILES: 163
# Data points without Uniprot ID: 517
# Data points without KEGG ID, SMILES and Uniprot ID: 52
#
# iLB1027_lipid
# For 944 out of 7077 reactions we don't have a Uniprot ID.
# There are 25369 KM data points
# Data points without KEGG ID and SMILES: 10106
# Data points without Uniprot ID: 3410
# Data points without KEGG ID, SMILES and Uniprot ID: 678
#
# iML1515
# For 260 out of 2206 reactions we don't have a Uniprot ID.
# There are 7714 KM data points
# Data points without KEGG ID and SMILES: 1176
# Data points without Uniprot ID: 1011
# Data points without KEGG ID, SMILES and Uniprot ID: 253
#
# iMM1415
# For 1513 out of 5138 reactions we don't have a Uniprot ID.
# There are 19054 KM data points
# Data points without KEGG ID and SMILES: 2896
# Data points without Uniprot ID: 5170
# Data points without KEGG ID, SMILES and Uniprot ID: 561
#
# iMM904
# For 304 out of 1393 reactions we don't have a Uniprot ID.
# There are 5645 KM data points
# Data points without KEGG ID and SMILES: 513
# Data points without Uniprot ID: 1278
# Data points without KEGG ID, SMILES and Uniprot ID: 117
#
# iND750
# For 213 out of 1073 reactions we don't have a Uniprot ID.
# There are 4240 KM data points
# Data points without KEGG ID and SMILES: 312
# Data points without Uniprot ID: 868
# Data points without KEGG ID, SMILES and Uniprot ID: 52
#
# iNJ661
# For 258 out of 987 reactions we don't have a Uniprot ID.
# There are 3985 KM data points
# Data points without KEGG ID and SMILES: 394
# Data points without Uniprot ID: 1042
# Data points without KEGG ID, SMILES and Uniprot ID: 150
#
# iNRG857_1313
# For 280 out of 1980 reactions we don't have a Uniprot ID.
# There are 7102 KM data points
# Data points without KEGG ID and SMILES: 988
# Data points without Uniprot ID: 1067
# Data points without KEGG ID, SMILES and Uniprot ID: 277
#
# iPC815
# For 122 out of 1288 reactions we don't have a Uniprot ID.
# There are 4696 KM data points
# Data points without KEGG ID and SMILES: 593
# Data points without Uniprot ID: 515
# Data points without KEGG ID, SMILES and Uniprot ID: 94
#
# iSbBS512_1146
# For 294 out of 1852 reactions we don't have a Uniprot ID.
# There are 6636 KM data points
# Data points without KEGG ID and SMILES: 924
# Data points without Uniprot ID: 1080
# Data points without KEGG ID, SMILES and Uniprot ID: 253
#
# iSBO_1134
# For 280 out of 1808 reactions we don't have a Uniprot ID.
# There are 6501 KM data points
# Data points without KEGG ID and SMILES: 928
# Data points without Uniprot ID: 1061
# Data points without KEGG ID, SMILES and Uniprot ID: 249
#
# iSDY_1059
# For 283 out of 1770 reactions we don't have a Uniprot ID.
# There are 6426 KM data points
# Data points without KEGG ID and SMILES: 936
# Data points without Uniprot ID: 1085
# Data points without KEGG ID, SMILES and Uniprot ID: 243
#
# iSFV_1184
# For 290 out of 1849 reactions we don't have a Uniprot ID.
# There are 6658 KM data points
# Data points without KEGG ID and SMILES: 927
# Data points without Uniprot ID: 1096
# Data points without KEGG ID, SMILES and Uniprot ID: 270
#
# iSFxv_1172
# For 270 out of 1862 reactions we don't have a Uniprot ID.
# There are 6671 KM data points
# Data points without KEGG ID and SMILES: 918
# Data points without Uniprot ID: 1040
# Data points without KEGG ID, SMILES and Uniprot ID: 262
#
# iSF_1195
# For 239 out of 1865 reactions we don't have a Uniprot ID.
# There are 6697 KM data points
# Data points without KEGG ID and SMILES: 932
# Data points without Uniprot ID: 937
# Data points without KEGG ID, SMILES and Uniprot ID: 238
#
# iSSON_1240
# For 274 out of 1922 reactions we don't have a Uniprot ID.
# There are 6905 KM data points
# Data points without KEGG ID and SMILES: 968
# Data points without Uniprot ID: 1060
# Data points without KEGG ID, SMILES and Uniprot ID: 256
#
# iS_1188
# For 237 out of 1853 reactions we don't have a Uniprot ID.
# There are 6653 KM data points
# Data points without KEGG ID and SMILES: 919
# Data points without Uniprot ID: 926
# Data points without KEGG ID, SMILES and Uniprot ID: 237
#
# iUTI89_1310
# For 265 out of 1973 reactions we don't have a Uniprot ID.
# There are 7072 KM data points
# Data points without KEGG ID and SMILES: 984
# Data points without Uniprot ID: 1012
# Data points without KEGG ID, SMILES and Uniprot ID: 261
#
# iWFL_1372
# For 269 out of 2020 reactions we don't have a Uniprot ID.
# There are 7238 KM data points
# Data points without KEGG ID and SMILES: 995
# Data points without Uniprot ID: 1027
# Data points without KEGG ID, SMILES and Uniprot ID: 269
#
# iYL1228
# For 151 out of 1751 reactions we don't have a Uniprot ID.
# There are 6259 KM data points
# Data points without KEGG ID and SMILES: 655
# Data points without Uniprot ID: 585
# Data points without KEGG ID, SMILES and Uniprot ID: 61
#
# iYO844
# For 89 out of 1026 reactions we don't have a Uniprot ID.
# There are 4104 KM data points
# Data points without KEGG ID and SMILES: 221
# Data points without Uniprot ID: 395
# Data points without KEGG ID, SMILES and Uniprot ID: 32
#
# iZ_1308
# For 298 out of 1971 reactions we don't have a Uniprot ID.
# There are 7084 KM data points
# Data points without KEGG ID and SMILES: 1005
# Data points without Uniprot ID: 1138
# Data points without KEGG ID, SMILES and Uniprot ID: 299
#
# RECON1
# For 1561 out of 5489 reactions we don't have a Uniprot ID.
# There are 20406 KM data points
# Data points without KEGG ID and SMILES: 2989
# Data points without Uniprot ID: 5396
# Data points without KEGG ID, SMILES and Uniprot ID: 610
#
# Recon3D
# For 3811 out of 15553 reactions we don't have a Uniprot ID.
# There are 57954 KM data points
# Data points without KEGG ID and SMILES: 13187
# Data points without Uniprot ID: 12411
# Data points without KEGG ID, SMILES and Uniprot ID: 2666
#
# yeast8
# For 597 out of 3488 reactions we don't have a Uniprot ID.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-883daa977bd8> in <module>
#      18     df_KM = create_KM_DataFrame(df_reactions)
#      19     df_KM = get_kegg_and_bigg_compound_ids(df_KM,  model_metabolites, model_metabolites_list)
# ---> 20     df_KM = add_substrate_name(df_KM)
#      21     df_KM = find_KEGG_ID_by_synonym(df_KM)
#      22     df_KM = download_SMILES_or_KEGG_from_MetaNetX(df_KM)
#
# ~\projects\GitHub\KM_prediction_function\code\BiGG_Models\downloading_BiGG_models.py in add_substrate_name(df_KM)
#     132     for ind in df_KM.index:
#     133         bigg_metabolite = df_KM["bigg.metabolite"][ind]
# --> 134         df_KM["substrate name"][ind] = bigg_metabolites[bigg_metabolites_list.index(bigg_metabolite)]["name"]
#     135     return(df_KM)
#     136
#
# ValueError: 'l' is not in list
